# %%
from aequilibrae.project import Project
from os.path import join, isfile, isdir

from functions.plot_subdivisions import plot_subdivisions

# %%
model_place = 'Armenia'

# %%
folder = f'/home/jovyan/workspace/road_analytics/{model_place}'

if isdir(folder):
    print(folder)
# Out:
# /home/jovyan/workspace/road_analytics/Armenia

# %%
project = Project()
project.open(folder)

# %%
plot_subdivisions(model_place, level=1)

# %%
project.close()
